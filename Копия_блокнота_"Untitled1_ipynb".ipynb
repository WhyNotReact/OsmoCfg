# %% [markdown]
# <a href="https://colab.research.google.com/github/WhyNotReact/OsmoCfg/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from google.colab import files

# %%
uploaded = files.upload()

print(uploaded)

df = pd.read_csv('housing.csv', delimiter=',')
df
# Out:
#      <input type="file" id="files-058f175b-f124-44ec-8c86-c6c91cdf0f9b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-058f175b-f124-44ec-8c86-c6c91cdf0f9b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(*(x for x in df))
# Out:
# longitude latitude housing_median_age total_rooms total_bedrooms population households median_income median_house_value ocean_proximity

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_nodup = df.drop_duplicates()
df_nodup = df_nodup.reset_index(drop=True)

df_nodup
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_nodup.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df_nodup['total_bedrooms'] = df_nodup['total_bedrooms'].fillna(df_nodup['total_bedrooms'].median())

# %%
df_nodup.head(6)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# ...

# %%
df_nodup.tail(6)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20634    -121.56     39.27                28.0       2332.0           395.0
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20634      1041.0       344.0         3.7125            116800.0
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# ...

# %%
cat_columns = []
num_columns = []

for col in df_nodup.columns:
    if df_nodup[col].dtype == object:
        cat_columns.append(col)
    else:
        num_columns.append(col)

print(cat_columns)
print(num_columns)
# Out:
# ['ocean_proximity']
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

# %%
df_nodup[num_columns].corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069120 -0.066484           -0.319026     0.927058
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069120    0.099773    0.055310      -0.015176
# latitude                 -0.066484   -0.108785   -0.071035      -0.079809
# ...

# %%
df = df_nodup.copy()

df['rooms_per_household'] = df['total_rooms'] / df['households']
df['bedrooms_per_room'] = df['total_bedrooms'] / df['total_rooms']
df['population_per_household'] = df['population'] / df['households']

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_norm = df.copy()

x_min = df[num_columns].min()
x_max = df[num_columns].max()

df_norm[num_columns] = (df[num_columns] - x_min) / (x_max - x_min)

df_norm
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       0.211155  0.567481            0.784314     0.022331        0.019863
# 1       0.212151  0.565356            0.392157     0.180503        0.171477
# 2       0.210159  0.564293            1.000000     0.037260        0.029330
# 3       0.209163  0.564293            1.000000     0.032352        0.036313
# 4       0.209163  0.564293            1.000000     0.041330        0.043296
# ...          ...       ...                 ...          ...             ...
# 20635   0.324701  0.737513            0.470588     0.042296        0.057883
# 20636   0.312749  0.738576            0.333333     0.017676        0.023122
# 20637   0.311753  0.732200            0.313725     0.057277        0.075109
# 20638   0.301793  0.732200            0.333333     0.047256        0.063315
# 20639   0.309761  0.725824            0.294118     0.070782        0.095438
#
# ...

# %%
df = df_norm

# %%
df['ocean_proximity'] = df['ocean_proximity'].astype('category')
df['ocean_proximity'] = df['ocean_proximity'].cat.codes

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       0.211155  0.567481            0.784314     0.022331        0.019863
# 1       0.212151  0.565356            0.392157     0.180503        0.171477
# 2       0.210159  0.564293            1.000000     0.037260        0.029330
# 3       0.209163  0.564293            1.000000     0.032352        0.036313
# 4       0.209163  0.564293            1.000000     0.041330        0.043296
# ...          ...       ...                 ...          ...             ...
# 20635   0.324701  0.737513            0.470588     0.042296        0.057883
# 20636   0.312749  0.738576            0.333333     0.017676        0.023122
# 20637   0.311753  0.732200            0.313725     0.057277        0.075109
# 20638   0.301793  0.732200            0.333333     0.047256        0.063315
# 20639   0.309761  0.725824            0.294118     0.070782        0.095438
#
# ...

# %%
plt.hist(df['median_house_value'], bins=50, edgecolor='black')
plt.title('House price distribution')
plt.xlabel('median_house_value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(df['median_income'], bins=50, edgecolor='black')
plt.title('Median income')
plt.xlabel('median_income')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10,7))

sns.scatterplot(
    data=df,
    x="median_income",
    y="median_house_value",
    hue="ocean_proximity",
    alpha=0.7
)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
dx = df.drop(columns=['median_house_value']).copy()
dy = df['median_house_value'].copy()

# %%
x = np.array(dx)
y = np.array(dy)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(dx)

X_train, X_test, y_train, y_test = train_test_split(
    scaled_data, dy,
    test_size=0.1,
    random_state=42
)

# %%
import tensorflow as tf

model = tf.keras.Sequential()

model.add(tf.keras.Input(shape=(12,)))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='linear'))

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss='mse',
    metrics=['mae']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32
)
# Out:
# Epoch 1/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0304 - mae: 0.1159
# Epoch 2/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0158 - mae: 0.0886
# Epoch 3/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0151 - mae: 0.0862
# Epoch 4/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0148 - mae: 0.0838
# Epoch 5/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0154 - mae: 0.0858
# Epoch 6/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0502 - mae: 0.0860
# Epoch 7/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0137 - mae: 0.0814
# Epoch 8/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0132 - mae: 0.0798
# Epoch 9/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0131 - mae: 0.0790
# Epoch 10/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0127 - mae: 0.0782
# Epoch 11/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - mae: 0.0773
# Epoch 12/50
# ...

# %%
plt.plot(history.history['loss'])
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0123 - mae: 0.0743
# [0.012312943115830421, 0.07434888184070587]

# %%
pred = model.predict(X_test)

residuals = y_test.values - pred.flatten()

residuals
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# array([-0.02771999, -0.15356243,  0.29855776, ..., -0.07427585,
#         0.05268019, -0.00558732])
